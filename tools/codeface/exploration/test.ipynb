# %%
library(pheatmap)

dat <- matrix(rnorm(100, 3, 1), ncol = 10)
names(dat) <- paste("X", 1:10)
pheatmap(dat, display_numbers = T, labels_row = T, 
         color = colorRampPalette(c("white", "red"))(100),
         cluster_rows = F, cluster_cols = F, fontsize_number = 15)
# Out:
# plot without title
